# %%
import numpy as np

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([ 3,  6,  5,  9,  7, 17, 16,  6, 16, 18])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[ 3,  6,  5,  9,  7],
#        [17, 16,  6, 16, 18]])

# %%
arr.max()
# Out:
# 18

# %%
matriz.max(1)
# Out:
# array([ 9, 18])

# %%
matriz.max(0)
# Out:
# array([17, 16,  6, 16, 18])

# %%
arr.argmax()
# Out:
# 9

# %%
matriz.argmax(0)
# Out:
# array([1, 1, 1, 1, 1])

# %%
arr.min()
# Out:
# 3

# %%
matriz.min(1)
# Out:
# array([3, 6])

# %%
matriz.argmin(1)
# Out:
# array([0, 2])

# %%
arr.argmin()
# Out:
# 0

# %%
arr.ptp()
# Out:
# 15

# %%
matriz.ptp(0)
# Out:
# array([ 6, 11, 10, 11, 11])

# %%
arr.sort()
arr
# Out:
# array([ 3,  5,  6,  6,  7,  9, 16, 16, 17, 18])

# %%
np.percentile(arr,50)
# Out:
# 8.0

# %%
np.median(matriz,0)
# Out:
# array([ 6. , 10.5, 11. , 11.5, 12.5])

# %%
np.std(matriz,1)
# Out:
# array([1.356466  , 3.18747549])

# %% [markdown]
# la varianza es la desviación estandar al cuadrado

# %%
np.std(arr) ** 2
# Out:
# 30.01

# %%
np.var(arr)
# Out:
# 30.01

# %%
np.mean(arr)
# Out:
# 10.3

# %%
a = np.array([[1,2],[3,4]])
b = np.array([5,6])

# %%
b = np.expand_dims(b,axis=0)
b
# Out:
# array([[5, 6]])

# %%
np.concatenate((a,b),axis=0)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
b.T
# Out:
# array([[5],
#        [6]])

# %%
np.concatenate((a,b.T),axis=1)
# Out:
# array([[1, 2, 5],
#        [3, 4, 6]])

# %%
np.real(arr)
# Out:
# array([ 3,  5,  6,  6,  7,  9, 16, 16, 17, 18])
