# %%
import numpy as np

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([10,  1,  5,  9, 15,  7,  8, 10, 11, 13])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[10,  1,  5,  9, 15],
#        [ 7,  8, 10, 11, 13]])

# %%
arr.max()
# Out:
# 15

# %%
matriz.max(1)
# Out:
# array([15, 13])

# %%
matriz.max(0)

# %%
arr.argmax()
# Out:
# 4

# %%
matriz.argmax(0)
# Out:
# array([0, 1, 1, 1, 0])

# %%
arr.min()
# Out:
# 1

# %%
matriz.min(1)
# Out:
# array([1, 7])

# %%
matriz.argmin(1)
# Out:
# array([1, 0])

# %%
arr.argmin()
# Out:
# 1

# %%
arr.ptp()
# Out:
# 14

# %%
matriz.ptp(0)
# Out:
# array([3, 7, 5, 2, 2])

# %%
arr.sort()
arr
# Out:
# array([ 1,  5,  7,  8,  9, 10, 10, 11, 13, 15])

# %%
np.percentile(arr,50)
# Out:
# 9.5

# %%
np.median(matriz,0)
# Out:
# array([ 5.5,  7.5,  9. , 10.5, 12. ])

# %%
np.std(matriz,1)
# Out:
# array([2.82842712, 1.93907194])

# %% [markdown]
# la varianza es la desviación estandar al cuadrado

# %%
np.std(arr) ** 2
# Out:
# 14.29

# %%
np.var(arr)
# Out:
# 14.289999999999997

# %%
np.mean(arr)
# Out:
# 8.9

# %%
a = np.array([[1,2],[3,4]])
b = np.array([5,6])

# %%
b = np.expand_dims(b,axis=0)
b
# Out:
# array([[5, 6]])

# %%
np.concatenate((a,b),axis=0)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
b.T
# Out:
# array([[5],
#        [6]])

# %%
np.concatenate((a,b.T),axis=1)
# Out:
# array([[1, 2, 5],
#        [3, 4, 6]])

# %%
np.real(arr)
# Out:
# array([ 1,  5,  7,  8,  9, 10, 10, 11, 13, 15])
