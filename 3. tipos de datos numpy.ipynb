# %%
import numpy as np
import pandas as pd

# %%
arr = np.array([3,6,9], dtype='int')
arr.dtype
# Out:
# dtype('int64')

# %%
arr = arr.astype(np.float64)
arr.dtype
# Out:
# dtype('float64')

# %%
arr = arr.astype(np.bool_)
arr
# Out:
# array([ True,  True,  True])

# %%
arr = arr.astype(np.string_)
arr
# Out:
# array([b'True', b'True', b'True'], dtype='|S5')
