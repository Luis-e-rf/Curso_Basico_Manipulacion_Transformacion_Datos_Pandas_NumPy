# %%
import numpy as np

# %%
arr = np.random.randint(1,10,(3,4))
print(arr)
arr.shape
# Out:
# [[2 7 7 2]
#  [9 4 3 6]
#  [3 6 3 4]]
# (3, 4)

# %%
np.reshape(arr,(3,2,-1),'C')
# Out:
# array([[[2, 7],
#         [7, 2]],
#
#        [[9, 4],
#         [3, 6]],
#
#        [[3, 6],
#         [3, 4]]])
